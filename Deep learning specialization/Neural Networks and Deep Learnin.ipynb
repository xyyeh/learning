# %% [markdown]
# ### Week 4

# %% [markdown]
# #### Recognizing networks
# 1. To calculate how many layers in a network, we typically only count the hidden and output layers.
#
#    ![image.png](attachment:image.png)
# 2. We use the superscript $[0]$ to denote the inputs and $[L]$ to denote the output layer respectively for a L-layer neural network.
#
# #### Forward propagation
